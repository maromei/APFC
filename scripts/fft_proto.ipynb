# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.animation import FuncAnimation
from IPython.display import HTML
from mpl_toolkits.axes_grid1 import make_axes_locatable

sns.set_theme()
# %config InlineBackend.figure_formats = ['svg']
# %matplotlib qt

# %% [markdown]
# # Settings

# %%
lim = 5
M = 100

M_cutoff = 20

Bx = 1.
dB0 = 1.
n0 = 1.
v = 1.

t0 = 0.0001
dt = 0.0002
tmax = 0.01

sym_fix = True
init_type = "wave" # random, gauss, wave, wave-gauss

frame_time = 50
wave_f = np.array([0.2, 0.1, 0.4])

limit_radius = 1.
eps = 0.1

conturf_cbar_N = 100

# %% [markdown]
# # Simulation Function Definitions

# %%
#############
# CONSTANTS #
#############

def C(t):
    global n0
    return -1.* (t + 3. * n0)

def lbd(t):
    global n0
    return - 2. * t * n0

#############
# FUNCTIONS #
#############

def g_sq_hat_sym(eta_i):

    global kx2, kx3, kx4
    global ky2, ky3, ky4
    global G

    ret = kx4 + ky4
    ret += 2. * np.linalg.norm(G[eta_i]) * ( kx3 + ky3 )
    ret += 4. * np.linalg.norm(G[eta_i])**2 * ( kx2 + ky2 )

    return ret

def g_sq_hat_non_sym(eta_i):

    global kx2, kx3, kx4
    global ky2, ky3, ky4
    global G

    ret = kx4 + ky4
    ret += 2. * ( G[eta_i][0] * kx3 + G[eta_i][1] * ky3 )
    ret += 4. * np.linalg.norm(G[eta_i])**2 * ( kx2 + ky2 )

    return ret

g_sq_hat = g_sq_hat_sym if sym_fix else g_sq_hat_non_sym

def n_hat(eta_i, t):

    global etas, D

    poss_eta_is = {0, 1, 2}
    other_etas = list(poss_eta_is.difference({eta_i}))

    C_t = C(t)
    lbd_t = lbd(t)

    eta_abs = np.power(np.abs(etas[eta_i]), 2)
    eta_conj1 = np.conj(etas[other_etas[0]])
    eta_conj2 = np.conj(etas[other_etas[1]])

    n = (3. * D * eta_abs + lbd_t) * etas[eta_i]
    n += 2. * C_t * eta_conj1 * eta_conj2
    n = np.fft.fft2(n)

    return -1. * n * np.linalg.norm(G[eta_i])**2

def lagr_hat(eta_i, t):

    global A, etas, D, G, gamma

    G_op = g_sq_hat(eta_i)

    poss_eta_is = {0, 1, 2}
    other_etas = list(poss_eta_is.difference({eta_i}))

    eta_abs1 = np.power(np.abs(etas[other_etas[0]]), 2)
    eta_abs2 = np.power(np.abs(etas[other_etas[1]]), 2)

    Gm_sq = (np.linalg.norm(G[eta_i])**2).astype(complex)

    lagr = A * G_op
    lagr = lagr.astype(complex)
    lagr += 6. * D * np.fft.fft2(eta_abs1) 
    lagr += 6. * D * np.fft.fft2(eta_abs2)
    lagr += gamma

    return -1. * lagr * Gm_sq

def eta_routine(eta_i, t, dt):

    lagr = lagr_hat(eta_i, t)
    n = n_hat(eta_i, t)

    exp_lagr = np.exp(lagr * dt)

    n_eta = exp_lagr * np.fft.fft2(etas[eta_i])
    n_eta += (exp_lagr - 1.) / lagr * n 

    return np.fft.ifft2(n_eta)

# %% [markdown]
# # Plotting Functions / Simulation Run

# %%
def plot(eta_i):

    plt.ioff()

    global etas, xm, ym

    eta_sum = np.abs(etas[0]) + np.abs(etas[1]) + np.abs(etas[2])
    plt.figure(figsize=(13, 10))
    plt.contourf(xm, ym, eta_sum)
    plt.grid("on")
    plt.colorbar()
    plt.savefig(f"/home/max/projects/apfc/data/{eta_i}.svg", format="svg")

def update(frame):
    
    global t, dt, etas, xm, ym, fig, ax, i

    n_eta1 = eta_routine(0, t, dt)
    n_eta2 = eta_routine(1, t, dt)
    n_eta3 = eta_routine(2, t, dt)

    etas[0,:,:] = n_eta1
    etas[1,:,:] = n_eta2
    etas[2,:,:] = n_eta3

    eta_sum = np.abs(etas[0]) + np.abs(etas[1]) + np.abs(etas[2])

    ax.clear()

    cont = ax.contourf(xm, ym, eta_sum)
    ax.grid('on')
    plt.title(f"t = {t:.4f}, i = {i}, dt={dt:.4f}")

    if (t == t0):
        fig.colorbar(cont)

    t += dt
    i += 1

def plot_window(frame):

    global t, dt, etas, xm, ym, fig, ax, i, cax, conturf_cbar_N
    global Bx, dB0, n0, v

    n_eta1 = eta_routine(0, t, dt)
    n_eta2 = eta_routine(1, t, dt)
    n_eta3 = eta_routine(2, t, dt)

    etas[0,:,:] = n_eta1
    etas[1,:,:] = n_eta2
    etas[2,:,:] = n_eta3

    eta_sum = np.abs(etas[0]) + np.abs(etas[1]) + np.abs(etas[2])

    ax.cla()

    cont = ax.contourf(xm, ym, eta_sum, conturf_cbar_N)
    ax.grid('on')
    ax.set_title(f"t = {t:.4f}, i = {i}, dt={dt:.4f}\n$B^x={Bx:.4f}, \Delta B^0={dB0:.4f}, n_0={n0:.4f}, v={v:.4f}$")
    fig.colorbar(cont, cax=cax)
    plt.tight_layout()

    t += dt
    i += 1

def plot_window_max(frame):

    global t, dt, etas, xm, ym, fig, ax1, i, cax, conturf_cbar_N, ax2, max_vals, indices
    global Bx, dB0, n0, v

    n_eta1 = eta_routine(0, t, dt)
    n_eta2 = eta_routine(1, t, dt)
    n_eta3 = eta_routine(2, t, dt)

    etas[0,:,:] = n_eta1
    etas[1,:,:] = n_eta2
    etas[2,:,:] = n_eta3

    eta_sum = np.abs(etas[0]) + np.abs(etas[1]) + np.abs(etas[2])

    indices.append(i)
    max_vals.append(np.max(eta_sum))

    ax1.cla()
    ax2.cla()

    cont = ax1.contourf(xm, ym, eta_sum, conturf_cbar_N)
    ax1.grid('on')
    ax1.set_title(f"t = {t:.4f}, i = {i}, dt={dt:.4f}\n$B^x={Bx:.4f}, \Delta B^0={dB0:.4f}, n_0={n0:.4f}, v={v:.4f}$")
    ax2.plot(indices, max_vals)
    fig.colorbar(cont, cax=cax)
    plt.tight_layout()

    t += dt
    i += 1

# %% [markdown]
# # Init Simulation

# %%
N = 10 * M

A = Bx
D = v
gamma = dB0 + 3. * v * n0**2

G = [
    np.array([- np.sqrt(3.) / 2., -0.5]),
    np.array([0., 1.]),
    np.array([np.sqrt(3.) / 2., -0.5]),
]

###############
# REAL COORDS #
###############

x = np.linspace(-lim, lim, M)
y = x

xm, ym = np.meshgrid(x, y)

###############
# FREQ COORDS #
###############

kx = np.pi / np.max(x) * x
ky = kx # assuming even spacing

kxm, kym = np.meshgrid(kx, ky)

kx2 = np.power(kxm, 2)
kx3 = np.power(kxm, 3)
kx4 = np.power(kxm, 4)

ky2 = np.power(kym, 2)
ky3 = np.power(kym, 3)
ky4 = np.power(kym, 4)

#############
# INIT ETAS #
#############

cut = xm.shape[0] // 2

def generate_eta():
    return np.array([
        [
            complex(np.random.uniform(), np.random.uniform()) 
            if (cut - i)**2 + (cut - j)**2 <= M_cutoff**2 else complex(0., 0.)
            for j in range(xm.shape[0])
        ] for i in range(xm.shape[1])
    ])

def norm_dist(offset, sigma):

    global xm, ym

    prefac = 1. / (sigma * 2. * np.pi)
    expon = -1 * ( (xm - offset[0])**2 + (ym - offset[1])**2) / (2. * sigma**2)

    return prefac * np.exp(expon)

def wave(k, w):
    global xm, ym
    return np.sin(w * k[0] * xm + w * k[1] * ym)

def tanhmin(rads, eps):
    return .5 * (1. + np.tanh(-3. * rads / eps))

etas = np.zeros((3, xm.shape[0], xm.shape[1]), dtype=complex)

if (init_type == "random"):
    etas[0,:,:] = generate_eta()
    etas[1,:,:] = generate_eta()
    etas[2,:,:] = generate_eta()
elif (init_type == "wave-gauss"): 
    etas[0,:,:] = norm_dist(20. * G[0], 10.) + complex(0, 1) * norm_dist(20. * G[0] * 2., 10.) * wave(G[0], wave_f[0])
    etas[1,:,:] = norm_dist(20. * G[1], 10.) + complex(0, 1) * norm_dist(20. * G[1] * 2., 10.) * wave(G[1], wave_f[1])
    etas[2,:,:] = norm_dist(20. * G[2], 10.) + complex(0, 1) * norm_dist(20. * G[2] * 2., 10.) * wave(G[2], wave_f[2])
elif (init_type == "wave"):
    etas[0,:,:] = wave(G[0], wave_f[0])
    etas[1,:,:] = wave(G[1], wave_f[1])
    etas[2,:,:] = wave(G[2], wave_f[2])
elif (init_type == "gauss"):
    etas[0,:,:] = norm_dist(20. * G[0], 10.) + complex(0, 1) * norm_dist(20. * G[0] * 2., 10.)
    etas[1,:,:] = norm_dist(20. * G[1], 10.) + complex(0, 1) * norm_dist(20. * G[1] * 2., 10.)
    etas[2,:,:] = norm_dist(20. * G[2], 10.) + complex(0, 1) * norm_dist(20. * G[2] * 2., 10.)

if (limit_radius > 0.):

    rad = np.sqrt(xm**2 + ym**2) - limit_radius
    tan = tanhmin(rad, eps)

    for i in range(3):
        etas[i,:,:] *= tan

# %% [markdown]
# # Run routine

# %%
nstep = int(round(tmax / dt))

t = t0
i = 1

fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.set_aspect("equal")

div = make_axes_locatable(ax)
cax = div.append_axes("right", "5%", "5%")

#ani = FuncAnimation(fig, update, interval=1000, frames=100)
ani = FuncAnimation(plt.gcf(), plot_window, interval=frame_time, frames=100)
plt.show()

# %% [markdown]
# # Run routine with maximum val

# %%
nstep = int(round(tmax / dt))

t = t0
i = 1

fig = plt.figure()
ax = fig.add_subplot(1,1,1)

fig, (ax2, ax1) = plt.subplots(1, 2)

ax1.set_aspect("equal")

div = make_axes_locatable(ax1)
cax = div.append_axes("right", "5%", "5%")

indices = []
max_vals = []

#ani = FuncAnimation(fig, update, interval=1000, frames=100)
ani = FuncAnimation(plt.gcf(), plot_window_max, interval=frame_time, frames=100)
plt.show()

# %% [markdown]
# # Surface Energy

# %%
s = np.array(G)

plt.figure()
plt.scatter(s[:,0], s[:, 1])
